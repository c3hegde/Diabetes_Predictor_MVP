# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import os

# Set working directory to your project folder
project_path = '/content/drive/MyDrive/Github/Diabetes_Predictor_MVP'
os.chdir(project_path)

# Add 'app' folder to system path so imports like 'from app.utils import ...' work
sys.path.append(os.path.join(project_path, 'app'))

# Confirm working directory
print("Working directory set to:", os.getcwd())
# Out:
# Working directory set to: /content/drive/MyDrive/Github/Diabetes_Predictor_MVP

# %%
# !pip install streamlit

# %%
# %run /content/drive/MyDrive/Github/Diabetes_Predictor_MVP/app/utils.py

# %%
# !streamlit run /content/drive/MyDrive/Github/Diabetes_Predictor_MVP/app/app.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.229.184.232:8501
#
#   Stopping...
#   Stopping...

# %%
# %run /content/drive/MyDrive/Github/Diabetes_Predictor_MVP/app/app.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /content/drive/MyDrive/Github/Diabetes_Predictor_MVP/app/app.py in <module>
#       3 import pickle
#       4 import numpy as np
# ----> 5 from app.utils import preprocess_input
#       6
#       7 # Load model and scaler
#
# /content/drive/MyDrive/Github/Diabetes_Predictor_MVP/app/app.py in <module>
#       3 import pickle
#       4 import numpy as np
# ----> 5 from app.utils import preprocess_input
#       6
#       7 # Load model and scaler
#
# ModuleNotFoundError: No module named 'app.utils'; 'app' is not a package
